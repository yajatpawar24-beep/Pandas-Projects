# %% [markdown]
# ![A laptop screen with a person typing the word 'seo'](work_laptop.png)

# %% [markdown]
# Imagine working for a digital marketing agency, and the agency is approached by a massive online furniture retailer. They want to test your skills at creating large campaigns for all of their website. You are tasked with creating a prototype set of keywords for search campaigns for their sofas section. The client says that they want you to generate keywords for the following products:
#
# - sofas
# - convertible sofas
# - love seats
# - recliners
# - sofa beds
#
# The client is a low-cost retailer, offering many promotions and discounts. You will need to focus on such keywords. You will also need to move away from luxury keywords and topics, as you are targeting price-sensitive customers. Because they are going to be tight on budget, it would be good to focus on a tightly targeted set of keywords and make sure they are all set to exact and phrase match.
#
# Based on the brief above you will first need to generate a list of words, that together with the products given above would make for good keywords. Here are some examples:
#
# - Products: sofas, recliners
# - Words: buy, prices
#
# The resulting keywords: 'buy sofas', 'sofas buy', 'buy recliners', 'recliners buy', 'prices sofas', 'sofas prices', 'prices recliners', 'recliners prices'.
#
# As a final result, you want to have a DataFrame that looks like this:
#
# <table>
# <thead>
# <tr>
# <th>Campaign</th>
# <th>Ad Group</th>
# <th>Keyword</th>
# <th>Criterion Type</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1a</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1b</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_2</td>
# <td>keyword 2a</td>
# <td>Exact</td>
# </tr>
# </tbody>
# </table>

# %%
import pandas as pd

# %%
products = ['sofas','recliners','sofa beds','love seats','convertible sofas']
words = ['buy','shop','price','discount','sale','comfort']
keywords_list = []

# %%
for product in products:
    for word in words:
        keywords_list.append([product, product + '' + word])
        keywords_list.append([product, word + '' + product])

print(keywords_list)
# Out:
# [['sofas', 'sofasbuy'], ['sofas', 'buysofas'], ['sofas', 'sofasshop'], ['sofas', 'shopsofas'], ['sofas', 'sofasprice'], ['sofas', 'pricesofas'], ['sofas', 'sofasdiscount'], ['sofas', 'discountsofas'], ['sofas', 'sofassale'], ['sofas', 'salesofas'], ['sofas', 'sofascomfort'], ['sofas', 'comfortsofas'], ['recliners', 'reclinersbuy'], ['recliners', 'buyrecliners'], ['recliners', 'reclinersshop'], ['recliners', 'shoprecliners'], ['recliners', 'reclinersprice'], ['recliners', 'pricerecliners'], ['recliners', 'reclinersdiscount'], ['recliners', 'discountrecliners'], ['recliners', 'reclinerssale'], ['recliners', 'salerecliners'], ['recliners', 'reclinerscomfort'], ['recliners', 'comfortrecliners'], ['sofa beds', 'sofa bedsbuy'], ['sofa beds', 'buysofa beds'], ['sofa beds', 'sofa bedsshop'], ['sofa beds', 'shopsofa beds'], ['sofa beds', 'sofa bedsprice'], ['sofa beds', 'pricesofa beds'], ['sofa beds', 'sofa bedsdiscount'], ['sofa beds', 'discountsofa beds'], ['sofa beds', 'sofa bedssale'], ['sofa beds', 'salesofa beds'], ['sofa beds', 'sofa bedscomfort'], ['sofa beds', 'comfortsofa beds'], ['love seats', 'love seatsbuy'], ['love seats', 'buylove seats'], ['love seats', 'love seatsshop'], ['love seats', 'shoplove seats'], ['love seats', 'love seatsprice'], ['love seats', 'pricelove seats'], ['love seats', 'love seatsdiscount'], ['love seats', 'discountlove seats'], ['love seats', 'love seatssale'], ['love seats', 'salelove seats'], ['love seats', 'love seatscomfort'], ['love seats', 'comfortlove seats'], ['convertible sofas', 'convertible sofasbuy'], ['convertible sofas', 'buyconvertible sofas'], ['convertible sofas', 'convertible sofasshop'], ['convertible sofas', 'shopconvertible sofas'], ['convertible sofas', 'convertible sofasprice'], ['convertible sofas', 'priceconvertible sofas'], ['convertible sofas', 'convertible sofasdiscount'], ['convertible sofas', 'discountconvertible sofas'], ['convertible sofas', 'convertible sofassale'], ['convertible sofas', 'saleconvertible sofas'], ['convertible sofas', 'convertible sofascomfort'], ['convertible sofas', 'comfortconvertible sofas']]

# %%
keywords_df = pd.DataFrame(keywords_list, columns=['Ad Group','Keyword'])

# %%
keywords_df['Campaign'] = 'SEM_Sofas'
keywords_df['Criterion Type'] = 'Exact'

print(keywords_df)
# Out:
#              Ad Group                    Keyword   Campaign Criterion Type
# 0               sofas                   sofasbuy  SEM_Sofas          Exact
# 1               sofas                   buysofas  SEM_Sofas          Exact
# 2               sofas                  sofasshop  SEM_Sofas          Exact
# 3               sofas                  shopsofas  SEM_Sofas          Exact
# 4               sofas                 sofasprice  SEM_Sofas          Exact
# 5               sofas                 pricesofas  SEM_Sofas          Exact
# 6               sofas              sofasdiscount  SEM_Sofas          Exact
# 7               sofas              discountsofas  SEM_Sofas          Exact
# 8               sofas                  sofassale  SEM_Sofas          Exact
# 9               sofas                  salesofas  SEM_Sofas          Exact
# 10              sofas               sofascomfort  SEM_Sofas          Exact
# 11              sofas               comfortsofas  SEM_Sofas          Exact
# 12          recliners               reclinersbuy  SEM_Sofas          Exact
# 13          recliners               buyrecliners  SEM_Sofas          Exact
# 14          recliners              reclinersshop  SEM_Sofas          Exact
# 15          recliners              shoprecliners  SEM_Sofas          Exact
# 16          recliners             reclinersprice  SEM_Sofas          Exact
# 17          recliners             pricerecliners  SEM_Sofas          Exact
# 18          recliners          reclinersdiscount  SEM_Sofas          Exact
# 19          recliners          discountrecliners  SEM_Sofas          Exact
# 20          recliners              reclinerssale  SEM_Sofas          Exact
# 21          recliners              salerecliners  SEM_Sofas          Exact
# 22          recliners           reclinerscomfort  SEM_Sofas          Exact
# 23          recliners           comfortrecliners  SEM_Sofas          Exact
# 24          sofa beds               sofa bedsbuy  SEM_Sofas          Exact
# 25          sofa beds               buysofa beds  SEM_Sofas          Exact
# 26          sofa beds              sofa bedsshop  SEM_Sofas          Exact
# 27          sofa beds              shopsofa beds  SEM_Sofas          Exact
# 28          sofa beds             sofa bedsprice  SEM_Sofas          Exact
# 29          sofa beds             pricesofa beds  SEM_Sofas          Exact
# 30          sofa beds          sofa bedsdiscount  SEM_Sofas          Exact
# 31          sofa beds          discountsofa beds  SEM_Sofas          Exact
# 32          sofa beds              sofa bedssale  SEM_Sofas          Exact
# 33          sofa beds              salesofa beds  SEM_Sofas          Exact
# 34          sofa beds           sofa bedscomfort  SEM_Sofas          Exact
# 35          sofa beds           comfortsofa beds  SEM_Sofas          Exact
# 36         love seats              love seatsbuy  SEM_Sofas          Exact
# 37         love seats              buylove seats  SEM_Sofas          Exact
# 38         love seats             love seatsshop  SEM_Sofas          Exact
# 39         love seats             shoplove seats  SEM_Sofas          Exact
# 40         love seats            love seatsprice  SEM_Sofas          Exact
# 41         love seats            pricelove seats  SEM_Sofas          Exact
# 42         love seats         love seatsdiscount  SEM_Sofas          Exact
# 43         love seats         discountlove seats  SEM_Sofas          Exact
# 44         love seats             love seatssale  SEM_Sofas          Exact
# 45         love seats             salelove seats  SEM_Sofas          Exact
# 46         love seats          love seatscomfort  SEM_Sofas          Exact
# 47         love seats          comfortlove seats  SEM_Sofas          Exact
# 48  convertible sofas       convertible sofasbuy  SEM_Sofas          Exact
# 49  convertible sofas       buyconvertible sofas  SEM_Sofas          Exact
# 50  convertible sofas      convertible sofasshop  SEM_Sofas          Exact
# 51  convertible sofas      shopconvertible sofas  SEM_Sofas          Exact
# 52  convertible sofas     convertible sofasprice  SEM_Sofas          Exact
# 53  convertible sofas     priceconvertible sofas  SEM_Sofas          Exact
# 54  convertible sofas  convertible sofasdiscount  SEM_Sofas          Exact
# 55  convertible sofas  discountconvertible sofas  SEM_Sofas          Exact
# 56  convertible sofas      convertible sofassale  SEM_Sofas          Exact
# 57  convertible sofas      saleconvertible sofas  SEM_Sofas          Exact
# 58  convertible sofas   convertible sofascomfort  SEM_Sofas          Exact
# 59  convertible sofas   comfortconvertible sofas  SEM_Sofas          Exact

# %%
keywords_df.to_csv('keywords.csv',index=False)
